# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sb

# %%
df = pd.read_csv("../data/df_match_ts_match_lg_11000.csv")

# %%
df.memory_usage().sum()/1024**3
# Out:
# 3.084389388561249

# %%
fig, ax = plt.subplots(figsize=(13,9))

sb.histplot(df, x='match_score', hue='type', log_scale=True)
# Out:
# <AxesSubplot:xlabel='match_score', ylabel='Count'>

# %%
df[(df['ts_1']=='M7427') & (df['type']=='fft')\
  & (df['match_score']==ms_max_fft)].sort_values('d_q50').head()
# Out:
#        ts_1    ts_2 type  match_score        d_m      d_mean        d_std  \
# 1240  M7427  M20141  fft        11111   0.660541   68.405797   124.218271
# 523   M7427   M9855  fft        11111  10.273799  311.594203   284.379893
# 1088  M7427  M19479  fft        11111  71.106646  892.898551  1217.737559
# 620   M7427  M16566  fft        11111   1.469407  217.560870    95.491143
# 280   M7427   M8728  fft        11111  10.072838  483.768116   282.193813
#
#           d_count  d_q25  d_q50   d_q75
# 1240  3616.507246   20.0    0.0    60.0
# 523   3616.507246    0.0    0.0   700.0
# 1088  3616.507246  350.0   40.0  2450.0
# 620   3616.507246  289.1   66.7   452.0
# 280   3616.507246  450.0   70.0  1000.0

# %%
ts_name = 'M7427'

# %%
ms_max_fft = df[(df['ts_1']=='M7427') & (df['type']=='fft')]['match_score'].max()
df_sub = df[(df['ts_1']=='M7427') & (df['type']=='fft')\
  & (df['match_score']==ms_max_fft)]

# %%
m_min_fft = df_sub['d_m'].min()
mean_min_fft = df_sub['d_mean'].min()
std_min_fft = df_sub['d_std'].min()
ts_q50_name = df_sub[df_sub['d_q50']==q50_min_fft].iloc[0,1]
q50_min_fft = df_sub['d_q50'].min()

ts_m_name = df_sub[df_sub['d_m']==m_min_fft].iloc[0,1]
ts_mean_name = df_sub[df_sub['d_mean']==mean_min_fft].iloc[0,1]
ts_std_name = df_sub[df_sub['d_std']==std_min_fft].iloc[0,1]
ts_q50_name = df_sub[df_sub['d_q50']==q50_min_fft].iloc[0,1]
ts_q50_name = df_sub[df_sub['d_q50']==q50_min_fft].iloc[0,1]
ts_q50_name = 'M20141' # chosen because q50 is 0.0 for multiple values (rest of metrics are better)

# %%
ar_orig = np.array(df_all[df_all['V1']==''].iloc[:,1:].dropna(axis=1))[0]
ar_m =  np.array(df_all[df_all['V1']==ts_m_name].iloc[:,1:].dropna(axis=1))[0]
ar_mean =  np.array(df_all[df_all['V1']==ts_mean_name].iloc[:,1:].dropna(axis=1))[0]
ar_std =  np.array(df_all[df_all['V1']==ts_std_name].iloc[:,1:].dropna(axis=1))[0]
ar_q25 =  np.array(df_all[df_all['V1']==ts_q25_name].iloc[:,1:].dropna(axis=1))[0]
ar_q50 =  np.array(df_all[df_all['V1']==ts_q50_name].iloc[:,1:].dropna(axis=1))[0]
ar_q75 =  np.array(df_all[df_all['V1']==ts_q65_name].iloc[:,1:].dropna(axis=1))[0]

# %%
fig, ax = plt.subplots(figsize=(13,9))
ax = plt.plot(ar_orig, label="original: "+ts_name)
# ax = plt.plot(ar_m, label="Delta M: "+ts_m_name)
# ax = plt.plot(ar_mean, label="Delta Mean: "+ ts_mean_name)
# ax = plt.plot(ar_std, label="Delta Std: "+ts_std_name)
ax = plt.plot(ar_q50, label="Delta q50: "+ts_q50_name)
plt.legend()

# %% [markdown]
# ### Read M4 TS data

# %%
df_hourly = pd.read_csv("../m4_data/hourly-train.csv")
df_daily = pd.read_csv("../m4_data/Daily-train.csv")
df_monthly = pd.read_csv("../m4_data/Monthly-train.csv")
df_quarterly = pd.read_csv("../m4_data/Quarterly-train.csv")
df_weekly = pd.read_csv("../m4_data/Weekly-train.csv")
df_yearly = pd.read_csv("../m4_data/Yearly-train.csv")
print(f"daily shape: {df_daily.shape}")
print(f"monthly shape: {df_monthly.shape}")
print(f"quarterly shape: {df_quarterly.shape}")
print(f"weekly shape: {df_weekly.shape}")
print(f"yearly shape: {df_yearly.shape}")
# Out:
# daily shape: (4227, 9920)
# monthly shape: (48000, 2795)
# quarterly shape: (24000, 867)
# weekly shape: (359, 2598)
# yearly shape: (23000, 836)

# %%
df[(df['ts_1']=='D4214')]['type'].unique()
# Out:
# array(['Hamming'], dtype=object)

# %%
ms_max = df[(df['ts_1']=='D4214') & (df['type']=='Hamming')]['match_score'].max()
ms_max_fft = df[(df['ts_1']=='D4214') & (df['type']=='fft')]['match_score'].max()
ms_max_wel = df[(df['ts_1']=='D4214') & (df['type']=='Welch')]['match_score'].max()

# %%
df[(df['type']=='fft')].head()
# Out:
#            ts_1    ts_2 type  match_score        d_m       d_mean  \
# 43273734  D3793  M41822  fft        11010  35.893000  4063.492125
# 43273735  D3793  M41825  fft        11010   8.864390  2907.003515
# 43273736  D3793  M41828  fft        11010  18.265747  1292.179448
# 43273737  D3793   M4183  fft        11010   5.938982  3622.929501
# 43273738  D3793  M41831  fft        11010   5.721387  3520.841106
#
#                 d_std      d_count     d_q25     d_q50     d_q75
# 43273734  7392.830510  4500.426471  1509.175   432.690  6771.495
# 43273735  1505.703026  4500.426471  4407.076  3650.437  1255.311
# 43273736  2905.246335  4500.426471  3924.935  2509.670  2041.415
# 43273737   642.100818  4647.426471  4245.625  3925.000  3002.625
# 43273738  1078.209452  4500.426471  4455.715  4188.840  2455.565

# %%
df_all = pd.concat([df_hourly, df_daily, df_monthly, df_quarterly, df_weekly, df_yearly])

# %%
df_hourly = None
df_daily = None
df_weekly = None
df_monthly = None
df_quarterly = None
df_yearly = None

# %%
ar1 = np.array(df_all[df_all['V1']=='D4214'].iloc[:,1:].dropna(axis=1))[0]
ar2 =  np.array(df_all[df_all['V1']=='W57'].iloc[:,1:].dropna(axis=1))[0]

# tests
ar3 =  np.array(df_all[df_all['V1']=='D1779'].iloc[:,1:].dropna(axis=1))[0]
ar4 =  np.array(df_all[df_all['V1']=='M26526'].iloc[:,1:].dropna(axis=1))[0]
ar4 =  np.array(df_all[df_all['V1']=='M26526'].iloc[:,1:].dropna(axis=1))[0]
ar5 =  np.array(df_all[df_all['V1']=='M41543'].iloc[:,1:].dropna(axis=1))[0]

# %%
fig, ax = plt.subplots(figsize=(13,9))
ax = plt.plot(ar1, label="original")
ax = plt.plot(ar2, label="W57")
ax = plt.plot(ar3, label="delta min m")
ax = plt.plot(ar4, label="delta min std")
ax = plt.plot(ar5, label="delta min+1 q50")
plt.legend()

# %% [markdown]
# ### Data Validation

# %%
df_stats = pd.read_csv("../data/df_stats.csv")

# %%
df_stats.head()
# Out:
#   ts_name                 freq_ids type          m            b  count  \
# 0  M41821  [184, 409, 166, 409, 0]  fft  -1.930820  8264.479369  477.0
# 1  M41822  [166, 409, 136, 409, 0]  fft  39.556878  -105.546726  477.0
# 2  M41823  [166, 409, 409, 136, 0]  fft  12.526905  -861.901341  477.0
# 3  M41824  [409, 166, 409, 136, 0]  fft  50.537625 -4350.076859  477.0
# 4  M41825  [166, 409, 136, 409, 0]  fft  12.528268  -862.019547  477.0
#
#           mean          std       min       q25       q50        q75  \
# 0  7796.651992  3055.512229  3412.000  5153.000  7231.000   9697.000
# 1  9040.918595  7698.172253  1777.240  3240.200  5447.190  11961.370
# 2  2069.459388  1829.340597   111.496   342.161  1398.506   3884.050
# 3  7490.976122  7581.540084   428.090   967.370  4876.480  14473.290
# 4  2070.422956  1811.044769   117.119   342.299  1364.063   3934.564
#
#          max  g
# 0  14718.000  M
# 1  32096.660  M
# 2   6941.477  M
# 3  26530.140  M
# 4   6637.992  M

# %%
df_stats['g'] = df_stats['ts_name'].astype(str).str[0]

# %%
sampl = df_stats.groupby('g')['ts_name'].sample(1).to_list()

# %%
df_stats[df_stats['ts_name'].isin(sampl)]
# Out:
#        ts_name                 freq_ids     type           m            b  \
# 1750    M43397  [201, 409, 170, 409, 0]      fft    4.955861  8454.483842
# 14212   Q11411  [262, 408, 409, 231, 0]      fft   62.280330  2336.231404
# 36962      W65    [68, 409, 99, 409, 0]      fft    4.686533  1574.923533
# 54636    Y5170  [276, 407, 408, 246, 0]      fft  105.981305   186.199805
# 76962      W65    [409, 99, 409, 68, 0]  Hamming    4.686533  1574.923533
# 94636    Y5170  [276, 407, 246, 408, 0]  Hamming  105.981305   186.199805
# 100336   D1300          [0, 0, 0, 0, 0]    Welch    3.204749  -924.154676
