# %%
from dtw import dtw, dtwPlotTwoWay, dtwPlotThreeWay
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("../m4_data/yearly-train.csv")

# %%
df.head()
# Out:
#    V1      V2      V3      V4      V5      V6      V7      V8      V9     V10  \
# 0  Y1  5172.1  5133.5  5186.9  5084.6  5182.0  5414.3  5576.2  5752.9  5955.2
# 1  Y2  2070.0  2104.0  2394.0  1651.0  1492.0  1348.0  1198.0  1192.0  1105.0
# 2  Y3  2760.0  2980.0  3200.0  3450.0  3670.0  3850.0  4000.0  4160.0  4290.0
# 3  Y4  3380.0  3670.0  3960.0  4190.0  4440.0  4700.0  4890.0  5060.0  5200.0
# 4  Y5  1980.0  2030.0  2220.0  2530.0  2610.0  2720.0  2970.0  2980.0  3100.0
#
#    ...  V827  V828  V829  V830  V831  V832  V833  V834  V835  V836
# 0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 836 columns]

# %%
sample
# Out:
# ['Y21565', 'Y13465']

# %%
sample
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/9b/qts_zvv52g90t2t7r2t45drw0000gn/T/ipykernel_27525/1007176509.py in <module>
# ----> 1 sample
#
# NameError: name 'sample' is not defined

# %%
sample
# Out:
# ['Y5683', 'Y5376']

# %%
sample = list(df['V1'].sample(2).values)
ar1 = np.array(df[df['V1']==sample[0]].iloc[:,1:].dropna(axis=1))[0]
ar2 = np.array(df[df['V1']==sample[1]].iloc[:,1:].dropna(axis=1))[0]
aln = dtw(ar1, ar2)
aln.plot()
dtwPlotTwoWay(aln, ar1, ar2)
# Out:
# <AxesSubplot:>

# %%
ax = dtwPlotTwoWay(aln, ar1, ar2)

# %%
fig_3way = dtwPlotThreeWay(aln, ar1, ar2)

# %%
ax.figure.savefig("../img/dtw_ex_plain.png")

# %%
fig_3way.figure.savefig("../img/dtw_3way.png")
