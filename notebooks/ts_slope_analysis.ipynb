# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("../data/df_stats.csv")

# %%
df_f = pd.read_csv("../data/df_freq_l.csv")

# %%
df_f.shape
# Out:
# (300000, 3)

# %%
plt.hist(df['m'], bins=200, log=True);

# %%
plt.hist(df['mean'], )
# Out:
# (array([9.999e+04, 8.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 2.000e+00]),
#  array([1.37437500e+01, 5.24978734e+04, 1.04982003e+05, 1.57466133e+05,
#         2.09950262e+05, 2.62434392e+05, 3.14918522e+05, 3.67402651e+05,
#         4.19886781e+05, 4.72370910e+05, 5.24855040e+05]),
#  <a list of 10 Patch objects>)

# %%
df_red = df[df['mean']<df['mean'].quantile(.99)]

# %%
fig, ax = plt.subplots(figsize=(13,9))
sns.histplot(df_red['mean'], kde=True);

# %%
df['mean'].quantile(.99)
# Out:
# 9874.392415294833

# %%
df['mean'].mean()
# Out:
# 4092.556004289816

# %%
df['mean'].min()
# Out:
# 13.74375

# %%
df['mean'].max()
# Out:
# 524855.04

# %%
1 == 1 == 1
# Out:
# True

# %%
1 == 1 == 2
# Out:
# False
